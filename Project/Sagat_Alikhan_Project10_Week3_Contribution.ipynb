# %% [markdown]
# # Week 1 (Proposal)

# %% [markdown]
# I contributed to dataset understanding and structure. I described that the dataset contains 303 rows and 14 columns, including medical features such as age, cholesterol, and chest pain type.

# %% [markdown]
# # Week 2 (EDA & Preprocessing)

# %% [markdown]
# I implemented the main exploratory data analysis and initial inspection.
#
# ### Dataset loading:

# %% [markdown]
# from ucimlrepo import fetch_ucirepo
#
# heart_disease = fetch_ucirepo(id=45)
#
# df = heart_disease.data.features.copy()
#
# df['target'] = heart_disease.data.targets

# %% [markdown]
# ### Basic inspection:

# %% [markdown]
# print(df.head())
#
# print(df.info())
#
# print(df.describe())
#
# print(df.isnull().sum())

# %% [markdown]
# From this, I identified:
#
# Dataset shape: (303, 14)
# Missing values: ca (4) and thal (2)

# %% [markdown]
# ### Class distribution:

# %% [markdown]
# import seaborn as sns
#
# sns.countplot(x='target', data=df)

# %% [markdown]
# ### Insight:
# Most patients do not have heart disease
# Among diseased, most cases are mild

# %% [markdown]
# ### Histograms:

# %% [markdown]
# df.hist(figsize=(12, 10))

# %% [markdown]
# ###  Insight:
# Most patients are between 40–60 years old

# %% [markdown]
# ### Boxplot:

# %% [markdown]
# sns.boxplot(x='target', y='thalach', data=df)

# %% [markdown]
# ###  Insight:
#
# Higher disease → lower heart rate (thalach decreases)

# %% [markdown]
# ### Correlation heatmap:

# %% [markdown]
# sns.heatmap(df.corr(), annot=True, cmap='coolwarm')

# %% [markdown]
# ###  Insight:
#
# Strongest predictors: cp and thalach

# %% [markdown]
# ### Scatter plot:

# %% [markdown]
# sns.scatterplot(x='age', y='chol', hue='target', data=df)

# %% [markdown]
# ###  Insight:
#
# Older age + high cholesterol → higher disease risk
# Week 3 (Modeling)

# %% [markdown]
# I supported modeling by providing insights from EDA to guide feature selection and model interpretation.

# %% [markdown]
# import matplotlib.pyplot as plt
#
# from ucimlrepo import fetch_ucirepo
#
# heart_disease = fetch_ucirepo(id=45)
#
# df = heart_disease.data.features.copy()
#
# df['target'] = heart_disease.data.targets

# %% [markdown]
# # Week 3 (Modeling)

# %% [markdown]
# I implemented the K-Nearest Neighbors (KNN) model to capture complex, non-linear patterns that the baseline model might have missed. After training the model and evaluating its performance, I utilized Pandas to integrate its results into a comparison table. I also conducted cross-validation to verify that the model's high performance was consistent across different subsets of the data.
#
# from sklearn.neighbors import KNeighborsClassifier
#
# knn = KNeighborsClassifier(n_neighbors=5)
#
# knn.fit(X_train_scaled, y_train)
#
# + KNN achieved the highest overall accuracy and precision.

# %% [markdown]
# # FINAL BLOCK
#
# This form is approved and signed by all team members:
#
# Alikhan Sagat
#
# Zhaslan Karakat
#
# Kenzhegaliyev Nursultan
#
# Azizbek Ainaz
