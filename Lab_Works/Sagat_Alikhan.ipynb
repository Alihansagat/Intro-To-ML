# %% [markdown]
# Task 1: Create Normal Headings (5 marks)
# <ul>
#     <li><h1>A level 1 heading: "My Title"</h1></li>
#     <li><h2>A level 2 heading: "My Subtitle"</h2></li>
#     <li><h3>A level 3 heading: "My Section"</h3></li>
# </ul>

# %% [markdown]
# Task 2: Center a Heading (10 marks)
# <h1 align="center">"Welcome to My Notebook"</h1>

# %% [markdown]
# Task 3: Insert an Image (10 marks)
# <img src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQLYoEEbl0LKW1hgwiOPCQMm6y9ySIAzwyf8Q&s">

# %% [markdown]
# Task 4: Resize an Image (10 marks)
# <img src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQLYoEEbl0LKW1hgwiOPCQMm6y9ySIAzwyf8Q&s" width="200">

# %% [markdown]
# Task 5: Image + Text Side by Side (15 marks)
# <table>
#     <tr>
#         <td>
#             <img src="https://cdn-fkmoj.nitrocdn.com/xvpOGZRTxJUhXKufpOYIruQcRqtvAAQX/assets/images/optimized/rev-4e1f421/media.briantracy.com/blog/wp-content/uploads/2024/01/23111730/Quote-17-.png" width="200" height="500">
#         </td>
#         <td>
#             <p>If you can change your mind, you can change
#             your life.</p>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# Task 6: Display 3 Images Side by Side (15 marks)
# <table>
#     <tr>
#         <td>
#             <img src="https://cdn-fkmoj.nitrocdn.com/xvpOGZRTxJUhXKufpOYIruQcRqtvAAQX/assets/images/optimized/rev-4e1f421/media.briantracy.com/blog/wp-content/uploads/2024/01/23111859/Quote-23.png" width="200" height="400">
#         </td>
#         <td>
#             <img src="https://itdworld.com/blog/wp-content/uploads/2024/04/motivational-words-for-employees.jpg" width="200" height="400">
#         </td>
#         <td>
#             <img src="https://cdn-fkmoj.nitrocdn.com/xvpOGZRTxJUhXKufpOYIruQcRqtvAAQX/assets/images/optimized/rev-4e1f421/media.briantracy.com/blog/wp-content/uploads/2024/01/23112014/Quote-29.png" width="200" height="400">
#         </td>
#     </tr>
# </table>

# %% [markdown]
# Challenging Task: Centered Title with an Image (10 marks)
# <table>
#     <tr>
#         <td>
#             <h1 align="center">"My Favorite Animal" -></h1>
#         </td>
#         <td>
#             <img src="https://petzpark.com.au/cdn/shop/articles/Breeds_Thumbnails_4_1_7e1838b3-7ffd-4b4f-a134-53975cc04315_900x.jpg?v=1764124922" width="200" height="400">
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table>
#     <tr>
#         <td><img src="https://petzpark.com.au/cdn/shop/articles/Breeds_Thumbnails_4_1_7e1838b3-7ffd-4b4f-a134-53975cc04315_900x.jpg?v=1764124922"></td>
#         <td><h1></h1></td>
#     </tr>
# </table>
